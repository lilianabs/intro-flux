# %% [markdown]
# # A simple liner regression example in Flux
#
# In this notebook, we go through a simple linear regression model using [Flux](https://fluxml.ai/) which is a Machine Learning library for Julia. This example is based on [this one](https://discourse.julialang.org/t/training-a-simple-linear-model-in-flux/24741/2).
#
# To train a ML model in Flux, we need to define the following **four** elements:
#
# * Data set
# * Parameters of the model
# * Objective function
# * Optimization routine

# %%
#Load the necessary packages
using Flux, Plots
using Flux: throttle, @epochs

#Backed for Plots
plotly()
# Out:
# ┌ Info: For saving to png with the Plotly backend ORCA has to be installed.
# └ @ Plots /home/liliana/.julia/packages/Plots/8GUYs/src/backends.jl:363
# Plots.PlotlyBackend()

# %% [markdown]
# ## Data set
#
# Usually, we start by obtaining the data set that we use to train our model and test it. For this example, we'll create some random data and reshape it so we can pass it to our model.
#
# We are creating a simple regression model with one input. Hence, we need to create a data set with one feature and a target variable.

# %%
X = rand(100);
Y = 0.5X + rand(100);

# %% [markdown]
# To visualize the data we just created, we plot a scatterplot with the feature `X` and target `Y`.

# %%
scatter(X, Y, title = "Data")
# Out:
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-latest.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="49d401f4-bfa9-4e9e-89ba-387d8dbef74c" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('49d401f4-bfa9-4e9e-89ba-387d8dbef74c');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.44723965531274446,
#             0.8805782329250562,
#             0.6891471013542825,
#             0.8228675219170647,
#             0.09681512215205679,
#             0.0259573373081885,
#             0.4096915470763729,
#             0.8857132019691534,
#             0.6886002747158277,
#             0.11983182472560583,
#             0.5487723643748135,
#             0.6811730693430387,
#             0.5621354840953292,
#             0.04072289024265974,
#             0.28304237317922754,
#             0.9569208644000791,
#             0.9894108273122559,
#             0.39168924473211786,
#             0.8652924473530073,
#             0.4408044036274661,
#             0.7417359407075923,
#             0.7322850271094992,
#             0.6246135880527277,
#             0.6680880317181785,
#             0.8408356867578632,
#             0.6928989852870804,
#             0.6614163379386655,
#             0.2900379055208393,
#             0.9413766832050181,
#             0.837660518924406,
#             0.9750554774930063,
#             0.5873554319114584,
#             0.7977594832398782,
#             0.5703126279166562,
#             0.3794952089574368,
#             0.18145215380047386,
#             0.6834227352628286,
#             0.6914233437343082,
#             0.7505999870286111,
#             0.4593925560709957,
#             0.023367067329127078,
#             0.7035089318214396,
#             0.21236869708199202,
#             0.7385922643535827,
#             0.9027983080018311,
#             0.0445610723701213,
#             0.7109540086266384,
#             0.6702074318348226,
#             0.5020240495658903,
#             0.09719799307645416,
#             0.13356088081408424,
#             0.1634334062008196,
#             0.22853001829159347,
#             0.5187186593631978,
#             0.6147654706685857,
#             0.11172682457313621,
#             0.5025595251151105,
#             0.21803207152037252,
#             0.8843716062340765,
#             0.00723037528870818,
#             0.10071707771910865,
#             0.19206295154578412,
#             0.396838010718257,
#             0.5202230408743962,
#             0.2939908841151331,
#             0.08313755378428334,
#             0.7147738693642895,
#             0.5883502297980436,
#             0.37034873784514377,
#             0.16097142818040755,
#             0.8546439690321856,
#             0.336654858720824,
#             0.031352646810333784,
#             0.5260744390376166,
#             0.4601480729900569,
#             0.9783653911987695,
#             0.3471699999229627,
#         ],
#         "domain": [
#             0.0658209390492855,
#             0.9934383202099738
#         ],
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",

# %% [markdown]
# The data we just created might not have a strong linear correlation but it is still useful for trying Flux out.
#
# We prepare the data for feeding it into the model.

# %%
#Zip the data
Xd = reduce(hcat,X)
Yd = reduce(hcat,Y)

data = [(Xd, Yd)];

# %% [markdown]
# Also, we prepare some test data for validating our model.

# %%
X_test = rand(20);
Y_test = 0.5X_test + rand(20);

# %%
Xd_test = reduce(hcat,X_test)
Yd_test = reduce(hcat,Y_test);

# %% [markdown]
# ## Model
#
# In Machine Learning, the simplest model is defined as $m = \sigma.(W*x + b)$. We can define this type of model by setting a neuron with no activation function. In Flux, we can use the [Dense function](https://fluxml.ai/Flux.jl/stable/models/layers/#Flux.Dense) to define this model:

# %%
m = Dense(1, 1)
# Out:
# Dense(1, 1)

# %% [markdown]
# Also, we need to obtain the parameters of the model so we can pass it to the train function we'll define below.

# %%
ps = Flux.params(m)
# Out:
# Params([Float32[1.5711069], Float32[0.0]])

# %% [markdown]
# When we create a model, Flux initializes the parameters with random values. At this point we obtain predictions with the current values for the parameters so that we can compare with the values obtained after training the model.

# %%
pred_0 = m(reduce(hcat,X));

# %% [markdown]
# ## Loss function
#
# Flux has many loss functions that we can use out of the box. For this example, we use the **MSE** loss function.

# %%
loss(x, y) = Flux.Losses.mse(m(x), y)
# Out:
# loss (generic function with 1 method)

# %% [markdown]
# ## Optimiser
#
# We need to set the optimization routine (optimiser) that we'll use to train our model. This optimiser will optimise the loss function.

# %%
#We use Gradient Descent with a learning rate of 0.3
opt = Descent(0.3)
# Out:
# Descent(0.3)

# %% [markdown]
# ## Train the model
#
# We have defined the four elements on a ML learning model listed above. Now, we can train our model so it can learn the best parameters. In Flux, we can execute a training step with the `Flux.train!` function.

# %%
Flux.train!(loss, ps, data, opt)

# %% [markdown]
# Flux allows us to create a *callback* function so that we can print information during the training process.

# %%
evalcb() = @show(loss(Xd_test, Yd_test))
# Out:
# evalcb (generic function with 1 method)

# %%
Flux.train!(loss, ps, data, opt, cb = throttle(evalcb, 2))
# Out:
# loss(Xd_test, Yd_test) = 0.16250049013328308

# %% [markdown]
# To train the model, we can either put the `Flux.train!` function inside a *for loop* or use the *@epoch* macro.

# %%
n_epochs = 10;

# %%
for i in 1:n_epochs
   Flux.train!(loss, ps, data, opt, cb = throttle(evalcb, 2)) 
end
# Out:
# loss(Xd_test, Yd_test) = 0.15450181473814584
# loss(Xd_test, Yd_test) = 0.14717197915347427
# loss(Xd_test, Yd_test) = 0.14041326737271484
# loss(Xd_test, Yd_test) = 0.13417323788131635
# loss(Xd_test, Yd_test) = 0.12841016209149103
# loss(Xd_test, Yd_test) = 0.12308689164509964
# loss(Xd_test, Yd_test) = 0.11816943823626977
# loss(Xd_test, Yd_test) = 0.11362645330748755
# loss(Xd_test, Yd_test) = 0.10942905136423535
# loss(Xd_test, Yd_test) = 0.10555058185910396

# %%
@epochs n_epochs Flux.train!(loss, ps, data, opt, cb = throttle(evalcb, 2))
# Out:
# loss(Xd_test, Yd_test) = 0.10196646369687228
# loss(Xd_test, Yd_test) = 0.09865406176066395
# loss(Xd_test, Yd_test) = 0.0955924369963102
# loss(Xd_test, Yd_test) = 0.09276229712212672
# loss(Xd_test, Yd_test) = 0.09014586688332635
# loss(Xd_test, Yd_test) = 0.08772673216203825
# loss(Xd_test, Yd_test) = 0.08548976512333001
# loss(Xd_test, Yd_test) = 0.08342097730918696
# loss(Xd_test, Yd_test) = 0.08150750332074282
# loss(Xd_test, Yd_test) = 0.07973742943444058
# ┌ Info: Epoch 1
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 2
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 3
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 4
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 5
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 6
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 7
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 8
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 9
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114
# ┌ Info: Epoch 10
# └ @ Main /home/liliana/.julia/packages/Flux/05b38/src/optimise/train.jl:114

# %%
#Final results 
pred_1 = m(reduce(hcat,X));

# %% [markdown]
# ## Results
#
# Now, we plot the final results to see how good the model is.

# %%
plot(X,Y, seriestype = :scatter)
plot!(Xd, pred_0, lc = :green)
plot!(Xd, pred_1)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="0b96702f-f011-4bc4-881d-9536189c20d0" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('0b96702f-f011-4bc4-881d-9536189c20d0');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.44723965531274446,
#             0.8805782329250562,
#             0.6891471013542825,
#             0.8228675219170647,
#             0.09681512215205679,
#             0.0259573373081885,
#             0.4096915470763729,
#             0.8857132019691534,
#             0.6886002747158277,
#             0.11983182472560583,
#             0.5487723643748135,
#             0.6811730693430387,
#             0.5621354840953292,
#             0.04072289024265974,
#             0.28304237317922754,
#             0.9569208644000791,
#             0.9894108273122559,
#             0.39168924473211786,
#             0.8652924473530073,
#             0.4408044036274661,
#             0.7417359407075923,
#             0.7322850271094992,
#             0.6246135880527277,
#             0.6680880317181785,
#             0.8408356867578632,
#             0.6928989852870804,
#             0.6614163379386655,
#             0.2900379055208393,
#             0.9413766832050181,
#             0.837660518924406,
#             0.9750554774930063,
#             0.5873554319114584,
#             0.7977594832398782,
#             0.5703126279166562,
#             0.3794952089574368,
#             0.18145215380047386,
#             0.6834227352628286,
#             0.6914233437343082,
#             0.7505999870286111,
#             0.4593925560709957,
#             0.023367067329127078,
#             0.7035089318214396,
#             0.21236869708199202,
#             0.7385922643535827,
#             0.9027983080018311,
#             0.0445610723701213,
#             0.7109540086266384,
#             0.6702074318348226,
#             0.5020240495658903,
#             0.09719799307645416,
#             0.13356088081408424,
#             0.1634334062008196,
#             0.22853001829159347,
#             0.5187186593631978,
#             0.6147654706685857,
#             0.11172682457313621,
#             0.5025595251151105,
#             0.21803207152037252,
#             0.8843716062340765,
#             0.00723037528870818,
#             0.10071707771910865,
#             0.19206295154578412,
#             0.396838010718257,
#             0.5202230408743962,
#             0.2939908841151331,
#             0.08313755378428334,
#             0.7147738693642895,
#             0.5883502297980436,
#             0.37034873784514377,
#             0.16097142818040755,
#             0.8546439690321856,
#             0.336654858720824,
#             0.031352646810333784,
#             0.5260744390376166,
#             0.4601480729900569,
#             0.9783653911987695,
#             0.3471699999229627,
